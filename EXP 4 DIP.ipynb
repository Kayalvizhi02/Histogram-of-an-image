# %%
import cv2

# %%
import matplotlib.pyplot as plt

# %%
Gray_image = cv2.imread('cat.jpg')

# %%
plt.imshow(Gray_image)
plt.show()

# %%
Color_image = cv2.imread('guitar.jpg')

# %%
plt.imshow(Color_image)
plt.show()
